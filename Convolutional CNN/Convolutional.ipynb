# %% [markdown]
# ## Libraries executar antes do load

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Preprocessing the Training Set executar antes do load

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,         
    shear_range=0.2,       
    zoom_range=0.2,           
    horizontal_flip=True      
)

train_set = train_datagen.flow_from_directory(
    'dataset/training_set/',
    target_size=(64, 64),   
    batch_size=32,
    class_mode='binary'       
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ## Preprocessing the Test Set executar antes do load

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# Carregar o conjunto de validação
test_set = test_datagen.flow_from_directory(
    'dataset/test_set/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Convolution Pooling Flattening

# %%
cnn = tf.keras.models.Sequential([
    
    tf.keras.layers.Input(shape=(64, 64, 3)),
    tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'),
    
    # pool_size janelas 2x2 que analisa, strides de quanto em quanto se passa na imagem
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    # Segunda camada
    tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    
    # Camada de achatamento (flatten) para transformar os dados 2D em um vetor 1D
    tf.keras.layers.Flatten(),
    
    # Camada totalmente conectada com 128 unidades e ativação ReLU
    tf.keras.layers.Dense(units=128, activation='relu'),
    
    # Camada de saída com 1 unidade e ativação sigmoide para classificação binária
    tf.keras.layers.Dense(units=1, activation='sigmoid')

])

# %% [markdown]
# ## Traning the CNN

# %%
cnn.compile( optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = cnn.fit(x = train_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# C:\Users\Gabriel\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 92ms/step - accuracy: 0.5280 - loss: 0.6972 - val_accuracy: 0.6625 - val_loss: 0.6137
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 91ms/step - accuracy: 0.6688 - loss: 0.6122 - val_accuracy: 0.6855 - val_loss: 0.6006
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 191ms/step - accuracy: 0.6992 - loss: 0.5662 - val_accuracy: 0.7190 - val_loss: 0.5380
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 129ms/step - accuracy: 0.7349 - loss: 0.5218 - val_accuracy: 0.7145 - val_loss: 0.5836
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.7613 - loss: 0.4908 - val_accuracy: 0.7450 - val_loss: 0.5219
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 91ms/step - accuracy: 0.7644 - loss: 0.4869 - val_accuracy: 0.7435 - val_loss: 0.5219
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.7830 - loss: 0.4667 - val_accuracy: 0.7305 - val_loss: 0.5647
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.7835 - loss: 0.4595 - val_accuracy: 0.7845 - val_loss: 0.4705
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.7846 - loss: 0.4481 - val_accuracy: 0.7885 - val_loss: 0.4715
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.7881 - loss: 0.4502 - val_accuracy: 0.7700 - val_loss: 0.5130
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8019 - loss: 0.4291 - val_accuracy: 0.7785 - val_loss: 0.4821
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.8062 - loss: 0.4068 - val_accuracy: 0.7600 - val_loss: 0.5008
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8063 - loss: 0.4195 - val_accuracy: 0.7860 - val_loss: 0.4768
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.8156 - loss: 0.4046 - val_accuracy: 0.7965 - val_loss: 0.4704
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8226 - loss: 0.3922 - val_accuracy: 0.8020 - val_loss: 0.4409
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8139 - loss: 0.3956 - val_accuracy: 0.7770 - val_loss: 0.4907
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 90ms/step - accuracy: 0.8230 - loss: 0.3828 - val_accuracy: 0.7865 - val_loss: 0.4879
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8363 - loss: 0.3641 - val_accuracy: 0.7960 - val_loss: 0.4736
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8337 - loss: 0.3635 - val_accuracy: 0.7730 - val_loss: 0.5379
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8416 - loss: 0.3505 - val_accuracy: 0.8010 - val_loss: 0.4548
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8535 - loss: 0.3363 - val_accuracy: 0.8100 - val_loss: 0.4592
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8474 - loss: 0.3458 - val_accuracy: 0.7955 - val_loss: 0.4571
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8604 - loss: 0.3249 - val_accuracy: 0.7550 - val_loss: 0.5929
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 89ms/step - accuracy: 0.8576 - loss: 0.3179 - val_accuracy: 0.8015 - val_loss: 0.4558
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8669 - loss: 0.3005 - val_accuracy: 0.8150 - val_loss: 0.4608

# %%
cnn.save('modelo_gato_cachorro.keras')

# %% [markdown]
# ## Resultados

# %%
## cnn = load_model('modelo_gato_cachorro.keras', compile=False)

# %%
# Plotando Acurácia
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Treinamento')
plt.plot(history.history['val_accuracy'], label='Validação')
plt.title('Acurácia durante o Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.legend()

plt.show()

# %%
# Plotando Loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Treinamento')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Loss durante o Treinamento e Validação')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
