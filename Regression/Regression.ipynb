# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel('Folds5x2_pp.xlsx')
dataset
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X
# Out:
# array([[  14.96,   41.76, 1024.07,   73.17],
#        [  25.18,   62.96, 1020.04,   59.08],
#        [   5.11,   39.4 , 1012.16,   92.14],
#        ...,
#        [  31.32,   74.33, 1012.92,   36.48],
#        [  24.48,   69.45, 1013.86,   62.39],
#        [  21.6 ,   62.52, 1017.23,   67.87]])

# %%
y
# Out:
# array([463.26, 444.37, 488.56, ..., 429.57, 435.74, 453.28])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
ann = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'), 
    tf.keras.layers.Dense(units=1) 
])

# %%
ann.compile( optimizer = 'adam', loss = 'mean_squared_error')

# %%
ann.fit( X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 482us/step - accuracy: 0.0000e+00 - loss: 27.9219
# Epoch 2/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.0000e+00 - loss: 27.5000
# Epoch 3/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.0000e+00 - loss: 28.0526
# Epoch 4/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.0000e+00 - loss: 27.7339
# Epoch 5/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - accuracy: 0.0000e+00 - loss: 27.1251
# Epoch 6/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - accuracy: 0.0000e+00 - loss: 28.3789
# Epoch 7/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.0000e+00 - loss: 26.9663
# Epoch 8/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.0000e+00 - loss: 27.2024
# Epoch 9/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.0000e+00 - loss: 26.6666
# Epoch 10/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.0000e+00 - loss: 26.7711
# Epoch 11/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - accuracy: 0.0000e+00 - loss: 26.1237
# Epoch 12/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.0000e+00 - loss: 27.6369
# Epoch 13/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.0000e+00 - loss: 26.4206
# Epoch 14/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - accuracy: 0.0000e+00 - loss: 25.6348
# Epoch 15/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - accuracy: 0.0000e+00 - loss: 26.4184
# Epoch 16/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.0000e+00 - loss: 26.2439
# Epoch 17/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.0000e+00 - loss: 27.3593
# Epoch 18/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.0000e+00 - loss: 28.2473
# Epoch 19/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - accuracy: 0.0000e+00 - loss: 26.2776
# Epoch 20/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - accuracy: 0.0000e+00 - loss: 26.4990
# Epoch 21/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - accuracy: 0.0000e+00 - loss: 26.1547
# Epoch 22/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.0000e+00 - loss: 26.8981
# Epoch 23/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - accuracy: 0.0000e+00 - loss: 26.4107
# Epoch 24/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.0000e+00 - loss: 27.3606
# Epoch 25/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - accuracy: 0.0000e+00 - loss: 25.9642
# Epoch 26/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - accuracy: 0.0000e+00 - loss: 26.1921
# Epoch 27/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.0000e+00 - loss: 26.3568
# Epoch 28/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.0000e+00 - loss: 25.2809
# Epoch 29/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.0000e+00 - loss: 28.5183
# Epoch 30/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.0000e+00 - loss: 26.0440
# Epoch 31/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.0000e+00 - loss: 27.1497
# Epoch 32/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.0000e+00 - loss: 26.5122
# Epoch 33/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.0000e+00 - loss: 26.5228
# Epoch 34/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - accuracy: 0.0000e+00 - loss: 25.6304
# Epoch 35/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.0000e+00 - loss: 26.1681
# Epoch 36/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.0000e+00 - loss: 26.8562
# Epoch 37/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - accuracy: 0.0000e+00 - loss: 26.0782
# Epoch 38/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.0000e+00 - loss: 27.0357
# Epoch 39/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.0000e+00 - loss: 27.0558
# Epoch 40/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.0000e+00 - loss: 26.1386
# Epoch 41/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - accuracy: 0.0000e+00 - loss: 27.4955
# Epoch 42/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - accuracy: 0.0000e+00 - loss: 25.8995
# Epoch 43/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.0000e+00 - loss: 26.5141
# Epoch 44/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.0000e+00 - loss: 26.9777
# Epoch 45/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - accuracy: 0.0000e+00 - loss: 27.0116
# Epoch 46/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.0000e+00 - loss: 26.8578
# Epoch 47/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.0000e+00 - loss: 27.6772
# Epoch 48/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.0000e+00 - loss: 25.4167
# Epoch 49/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - accuracy: 0.0000e+00 - loss: 26.8855
# Epoch 50/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - accuracy: 0.0000e+00 - loss: 26.6693
# Epoch 51/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.0000e+00 - loss: 25.4711
# Epoch 52/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - accuracy: 0.0000e+00 - loss: 26.3114
# Epoch 53/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.0000e+00 - loss: 27.2344
# Epoch 54/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.0000e+00 - loss: 27.2819
# Epoch 55/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.0000e+00 - loss: 27.4773
# Epoch 56/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.0000e+00 - loss: 26.2271
# Epoch 57/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.0000e+00 - loss: 26.1457
# Epoch 58/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.0000e+00 - loss: 26.0593
# Epoch 59/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.0000e+00 - loss: 26.1651
# Epoch 60/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - accuracy: 0.0000e+00 - loss: 26.0030
# Epoch 61/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - accuracy: 0.0000e+00 - loss: 26.6533
# Epoch 62/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - accuracy: 0.0000e+00 - loss: 27.3411
# Epoch 63/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.0000e+00 - loss: 26.7760
# Epoch 64/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - accuracy: 0.0000e+00 - loss: 26.1441
# Epoch 65/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - accuracy: 0.0000e+00 - loss: 26.0180
# Epoch 66/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - accuracy: 0.0000e+00 - loss: 26.1699
# Epoch 67/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - accuracy: 0.0000e+00 - loss: 26.4685
# Epoch 68/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - accuracy: 0.0000e+00 - loss: 26.3362
# Epoch 69/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.0000e+00 - loss: 26.3020
# Epoch 70/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - accuracy: 0.0000e+00 - loss: 26.4649
# Epoch 71/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.0000e+00 - loss: 27.1562
# Epoch 72/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - accuracy: 0.0000e+00 - loss: 26.2571
# Epoch 73/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - accuracy: 0.0000e+00 - loss: 27.1763
# Epoch 74/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - accuracy: 0.0000e+00 - loss: 26.6250
# Epoch 75/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.0000e+00 - loss: 27.6005
# Epoch 76/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - accuracy: 0.0000e+00 - loss: 26.0291
# Epoch 77/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.0000e+00 - loss: 28.1752
# Epoch 78/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - accuracy: 0.0000e+00 - loss: 26.2991
# Epoch 79/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - accuracy: 0.0000e+00 - loss: 26.1674
# Epoch 80/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - accuracy: 0.0000e+00 - loss: 27.3641
# Epoch 81/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - accuracy: 0.0000e+00 - loss: 25.7978
# Epoch 82/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - accuracy: 0.0000e+00 - loss: 28.8463
# Epoch 83/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - accuracy: 0.0000e+00 - loss: 26.1345
# Epoch 84/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - accuracy: 0.0000e+00 - loss: 26.0587
# Epoch 85/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - accuracy: 0.0000e+00 - loss: 27.0320
# Epoch 86/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - accuracy: 0.0000e+00 - loss: 26.8440
# Epoch 87/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - accuracy: 0.0000e+00 - loss: 25.6526
# Epoch 88/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.0000e+00 - loss: 26.3167
# Epoch 89/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - accuracy: 0.0000e+00 - loss: 26.1268
# Epoch 90/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - accuracy: 0.0000e+00 - loss: 26.5761
# Epoch 91/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.0000e+00 - loss: 26.6857
# Epoch 92/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - accuracy: 0.0000e+00 - loss: 26.4302
# Epoch 93/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - accuracy: 0.0000e+00 - loss: 27.3409
# Epoch 94/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.0000e+00 - loss: 26.8336
# Epoch 95/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - accuracy: 0.0000e+00 - loss: 26.1384
# Epoch 96/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - accuracy: 0.0000e+00 - loss: 27.0899
# Epoch 97/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.0000e+00 - loss: 26.5143
# Epoch 98/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - accuracy: 0.0000e+00 - loss: 27.3513
# Epoch 99/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - accuracy: 0.0000e+00 - loss: 27.9946
# Epoch 100/100
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - accuracy: 0.0000e+00 - loss: 25.9520

# %%
y_pred = ann.predict(X_test)
np.set_printoptions(precision=2)
result = np.column_stack((y_pred, y_test)) # Combine two arrays horizontal and transnform into a array with 2 columns apart
print(result[::])
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# [[430.9  431.23]
#  [461.92 460.01]
#  [465.4  461.14]
#  ...
#  [472.66 473.26]
#  [439.42 438.  ]
#  [458.65 463.28]]

# %%
plt.figure(figsize=(10, 6))                                #Transparência
plt.scatter(y_test, y_pred, color='blue', label='Previsões', alpha=0.9)
                # Eixo X                    #Eixo Y
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Linha Ideal')
plt.xlabel('Valores Reais')
plt.ylabel('Valores Previstos')
plt.title('Comparação entre Valores Reais e Previstos')
plt.legend() # Legenda em cima
plt.grid() # Linhas do gráfico
plt.show() # mostrar gráfico
